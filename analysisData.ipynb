# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
csv_file = "analysisData.csv"
df = pd.read_csv(csv_file)
df.head()
# Out:
#      state   county    fips  trump16  clinton16  otherpres16  romney12  \
# 0  Alabama  Autauga  1001.0  18172.0     5936.0        865.0   17379.0
# 1  Alabama  Baldwin  1003.0  72883.0    18458.0       3874.0   66016.0
# 2  Alabama  Barbour  1005.0   5454.0     4871.0        144.0    5550.0
# 3  Alabama     Bibb  1007.0   6738.0     1874.0        207.0    6132.0
# 4  Alabama   Blount  1009.0  22859.0     2156.0        573.0   20757.0
#
#    obama12  otherpres12  demsen16  ...  age29andunder_pct  age65andolder_pct  \
# 0   6363.0        190.0    6331.0  ...          40.037058          13.978456
# 1  18424.0        898.0   19145.0  ...          35.474412          18.714851
# 2   5912.0         47.0    4777.0  ...          37.664387          16.528895
# 3   2202.0         86.0    2082.0  ...          37.329435          14.885699
# 4   2970.0        279.0    2980.0  ...          37.240053          17.192916
#
#    median_hh_inc  clf_unemploy_pct  lesshs_pct  lesscollege_pct  \
# ...

# %%
df.columns
# Out:
# Index(['state', 'county', 'fips', 'trump16', 'clinton16', 'otherpres16',
#        'romney12', 'obama12', 'otherpres12', 'demsen16', 'repsen16',
#        'othersen16', 'demhouse16', 'rephouse16', 'otherhouse16', 'demgov16',
#        'repgov16', 'othergov16', 'repgov14', 'demgov14', 'othergov14',
#        'total_population', 'cvap', 'white_pct', 'black_pct', 'hispanic_pct',
#        'nonwhite_pct', 'foreignborn_pct', 'female_pct', 'age29andunder_pct',
#        'age65andolder_pct', 'median_hh_inc', 'clf_unemploy_pct', 'lesshs_pct',
#        'lesscollege_pct', 'lesshs_whites_pct', 'lesscollege_whites_pct',
#        'rural_pct', 'ruralurban_cc\'],
#       dtype='object')

# %%
df.describe()
# Out:
#                fips        trump16     clinton16    otherpres16  \
# count   3114.000000    3114.000000  3.114000e+03    3114.000000
# mean   30660.117855   20171.786448  2.110600e+04    2459.164419
# std    14984.811176   43162.140286  8.052001e+04    7514.783991
# min     1001.000000       0.000000  0.000000e+00       0.000000
# 25%    19039.500000    3216.250000  1.170000e+03     183.000000
# 50%    29210.000000    7239.500000  3.178000e+03     499.000000
# 75%    46006.500000   17886.000000  9.827750e+03    1674.000000
# max    56045.000000  769743.000000  2.464364e+06  200201.000000
#
#             romney12       obama12   otherpres12      demsen16       repsen16  \
# count    3114.000000  3.114000e+03   3114.000000  1.942000e+03    1942.000000
# mean    19433.805716  2.106226e+04    839.764611  2.574812e+04   19936.436148
# std     44577.392198  7.401418e+04   2949.902265  1.062836e+05   38095.362416
# ...

# %%
df["state"].value_counts()
# Out:
# Texas                   254
# Georgia                 159
# Virginia                134
# Kentucky                120
# Missouri                116
# Kansas                  105
# Illinois                102
# North Carolina          100
# Iowa                     99
# Tennessee                95
# Nebraska                 93
# Indiana                  92
# Ohio                     88
# Minnesota                87
# Michigan                 83
# Mississippi              82
# Oklahoma                 77
# Arkansas                 75
# Wisconsin                72
# Pennsylvania             67
# Alabama                  67
# Florida                  67
# South Dakota             66
# Louisiana                64
# Colorado                 64
# New York                 62
# California               58
# Montana                  56
# West Virginia            55
# North Dakota             53
# South Carolina           46
# Idaho                    44
# Washington               39
# ...

# %%
df.count()
# Out:
# state                     3115
# county                    3114
# fips                      3114
# trump16                   3114
# clinton16                 3114
# otherpres16               3114
# romney12                  3114
# obama12                   3114
# otherpres12               3114
# demsen16                  1942
# repsen16                  1942
# othersen16                1942
# demhouse16                2862
# rephouse16                2862
# otherhouse16              2862
# demgov16                   601
# repgov16                   601
# othergov16                 601
# repgov14                  2148
# demgov14                  2148
# othergov14                2148
# total_population          3111
# cvap                      3111
# white_pct                 3111
# black_pct                 3111
# hispanic_pct              3111
# nonwhite_pct              3111
# foreignborn_pct           3111
# female_pct                3111
# age29andunder_pct         3111
# ...

# %%
by_state = df.groupby(["state"])
trump_tot = by_state["trump16"].sum()
clinton_tot = by_state["clinton16"].sum()

summary = pd.DataFrame({"Trump":trump_tot, \
    "Clinton": clinton_tot})
summary
# Out:
#                           Trump    Clinton
# state
# Alabama               1318250.0   729547.0
# Arizona               1252401.0  1161167.0
# Arkansas               684872.0   380494.0
# California            4483810.0  8753788.0
# Colorado              1202484.0  1338870.0
# Connecticut            673215.0   897572.0
# Delaware               185127.0   235603.0
# District of Columbia    12723.0   282830.0
# Florida               4617886.0  4504975.0
# Georgia               2089104.0  1877963.0
# Hawaii                 128847.0   266891.0
# Idaho                  409055.0   189765.0
# Illinois              2146015.0  3090729.0
# Indiana               1557286.0  1033126.0
# Iowa                   800983.0   653669.0
# Kansas                 671018.0   427005.0
# Kentucky              1202971.0   628854.0
# Louisiana             1178638.0   780154.0
# Maine                  334945.0   354718.0
# Maryland               943169.0  1677928.0
# Massachusetts         1090893.0  1995196.0
# ...

# %%
df = df[['state', 'county', 'fips', 'total_population', 'cvap', 'white_pct',
      'black_pct', 'hispanic_pct',
       'nonwhite_pct', 'foreignborn_pct', 'female_pct', 'age29andunder_pct',
       'age65andolder_pct', 'median_hh_inc', 'clf_unemploy_pct', 'lesshs_pct',
       'lesscollege_pct', 'lesshs_whites_pct', 'lesscollege_whites_pct',
       'rural_pct']]
df.head()
# Out:
#      state   county    fips  total_population      cvap  white_pct  black_pct  \
# 0  Alabama  Autauga  1001.0           55049.0   40690.0  75.683482  18.370906
# 1  Alabama  Baldwin  1003.0          199510.0  151770.0  83.178788   9.225603
# 2  Alabama  Barbour  1005.0           26614.0   20375.0  45.885624  47.888329
# 3  Alabama     Bibb  1007.0           22572.0   17590.0  74.765196  21.212121
# 4  Alabama   Blount  1009.0           57704.0   42430.0  87.657701   1.557951
#
#    hispanic_pct  nonwhite_pct  foreignborn_pct  female_pct  age29andunder_pct  \
# 0      2.572254     24.316518         1.838362   51.176225          40.037058
# 1      4.366698     16.821212         3.269510   51.194928          35.474412
# 2      4.309762     54.114376         2.859397   46.498084          37.664387
# 3      2.223994     25.234804         1.351232   46.464646          37.329435
# 4      8.727298     12.342299         4.271801   50.485235          37.240053
#
# ...
