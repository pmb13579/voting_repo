# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
csv_file = "countypres_2000-2016.csv"
df = pd.read_csv(csv_file)
df.head()
# Out:
#    year    state state_po   county    FIPS     office       candidate  \
# 0  2000  Alabama       AL  Autauga  1001.0  President         Al Gore
# 1  2000  Alabama       AL  Autauga  1001.0  President  George W. Bush
# 2  2000  Alabama       AL  Autauga  1001.0  President     Ralph Nader
# 3  2000  Alabama       AL  Autauga  1001.0  President           Other
# 4  2000  Alabama       AL  Baldwin  1003.0  President         Al Gore
#
#         party  candidatevotes  totalvotes   version
# 0    democrat          4942.0     17208.0  20181011
# 1  republican         11993.0     17208.0  20181011
# 2       green           160.0     17208.0  20181011
# 3         NaN           113.0     17208.0  20181011
# 4    democrat         13997.0     56480.0  20181011

# %%
df.count()
# Out:
# year              50528
# state             50528
# state_po          50464
# county            50528
# FIPS              50464
# office            50528
# candidate         50528
# party             34738
# candidatevotes    50120
# totalvotes        49138
# version           50528
# dtype: int64

# %%
#delete rows with no candidate votes
df = df.loc[df["candidatevotes"].notna(), :]
df = df.loc[df["candidatevotes"] > 0, :]

# %%
# fix null fields for "other" party rows
df.loc[df['candidate'].eq('Other') & df['party'].isnull(), 'party'] = 'other'

# %%
# fix null FIPS fields, which only occurred for four states
df.loc[df['state'].eq('Alaska') & df['state_po'].isnull()& df['FIPS'].isnull(), 'FIPS'] = 0
df.loc[df['state'].eq('Maine') & df['state_po'].isnull()& df['FIPS'].isnull(), 'FIPS'] = 0
df.loc[df['state'].eq('Connecticut') & df['state_po'].isnull()& df['FIPS'].isnull(), 'FIPS'] = 0
df.loc[df['state'].eq('Rhode Island') & df['state_po'].isnull()& df['FIPS'].isnull(), 'FIPS'] = 0

# %%
# fix null state_po fields, which only occurred for four states
df.loc[df['state'].eq('Alaska') & df['state_po'].isnull(), 'state_po'] = 'AL'
df.loc[df['state'].eq('Maine') & df['state_po'].isnull(), 'state_po'] = 'ME'
df.loc[df['state'].eq('Connecticut') & df['state_po'].isnull(), 'state_po'] = 'CT'
df.loc[df['state'].eq('Rhode Island') & df['state_po'].isnull(), 'state_po'] = 'RI'

# %%
# now no null fields remain, except for totalvotes field which will not be used
df.count()
# Out:
# year              49952
# state             49952
# state_po          49952
# county            49952
# FIPS              49952
# office            49952
# candidate         49952
# party             49952
# candidatevotes    49952
# totalvotes        48970
# version           49952
# dtype: int64

# %%
# check year column - looks ok
counts = df["year"].value_counts()
counts
# Out:
# 2000    12332
# 2016     9468
# 2012     9391
# 2008     9382
# 2004     9379
# Name: year, dtype: int64

# %%
# check state_po column - looks ok since 51 rows for the 50 states plus DC
counts = df["state_po"].value_counts()
counts
# Out:
# TX    4053
# GA    2517
# VA    2141
# KY    1920
# MO    1852
# KS    1680
# IL    1632
# IA    1584
# TN    1520
# NC    1500
# NE    1487
# IN    1469
# OH    1408
# MN    1392
# MI    1328
# MS    1312
# AR    1200
# WI    1152
# AL    1075
# PA    1072
# FL    1072
# LA    1024
# CO    1020
# NY     992
# SD     990
# CA     928
# OK     924
# MT     896
# WV     880
# ND     848
# SC     736
# ID     704
# AK     640
# WA     624
# OR     576
# NM     528
# UT     464
# MD     384
# WY     368
# NJ     336
# NV     272
# ME     262
# AZ     240
# MA     224
# VT     224
# NH     160
# CT     131
# RI      83
# HI      64
# DE      48
# DC      16
# Name: state_po, dtype: int64

# %%
# add four new columns
df["dem_votes"] = 0
df["rep_votes"] = 0
df["oth_votes"] = 0
df["tot_votes"] = 0

# %%
# populate three of new columns with values
df.loc[df['party'].eq('democrat'), 'dem_votes'] = df["candidatevotes"]
df.loc[df['party'].eq('republican'), 'rep_votes'] = df["candidatevotes"]
df.loc[(df['party'] != 'democrat') & (df['party'] != 'republican'), 'oth_votes'] = df["candidatevotes"]

# %%
# to check calculations from last cell
df.head()
# Out:
#    year    state state_po   county    FIPS     office       candidate  \
# 0  2000  Alabama       AL  Autauga  1001.0  President         Al Gore
# 1  2000  Alabama       AL  Autauga  1001.0  President  George W. Bush
# 2  2000  Alabama       AL  Autauga  1001.0  President     Ralph Nader
# 3  2000  Alabama       AL  Autauga  1001.0  President           Other
# 4  2000  Alabama       AL  Baldwin  1003.0  President         Al Gore
#
#         party  candidatevotes  totalvotes   version  dem_votes  rep_votes  \
# 0    democrat          4942.0     17208.0  20181011     4942.0        0.0
# 1  republican         11993.0     17208.0  20181011        0.0    11993.0
# 2       green           160.0     17208.0  20181011        0.0        0.0
# 3       other           113.0     17208.0  20181011        0.0        0.0
# 4    democrat         13997.0     56480.0  20181011    13997.0        0.0
#
#    oth_votes  tot_votes
# 0        0.0          0
# 1        0.0          0
# 2      160.0          0
# 3      113.0          0
# 4        0.0          0

# %%
# delete some columns
df = df[["year", "state", "state_po", "county", "FIPS", "dem_votes",
         "rep_votes", "oth_votes", "tot_votes"]]

# calculate tot_votes column
df["tot_votes"] = df["dem_votes"] + df["rep_votes"] + df["oth_votes"]
df.head()
# Out:
#    year    state state_po   county    FIPS  dem_votes  rep_votes  oth_votes  \
# 0  2000  Alabama       AL  Autauga  1001.0     4942.0        0.0        0.0
# 1  2000  Alabama       AL  Autauga  1001.0        0.0    11993.0        0.0
# 2  2000  Alabama       AL  Autauga  1001.0        0.0        0.0      160.0
# 3  2000  Alabama       AL  Autauga  1001.0        0.0        0.0      113.0
# 4  2000  Alabama       AL  Baldwin  1003.0    13997.0        0.0        0.0
#
#    tot_votes
# 0     4942.0
# 1    11993.0
# 2      160.0
# 3      113.0
# 4    13997.0

# %%
# groupby
df1 = df.groupby(['year', 'state', 'county'])

# calculate summary data
state_abbr = df1["state_po"].min()
fips = df1["FIPS"].min()
dem = df1["dem_votes"].sum()
rep = df1["rep_votes"].sum()
oth = df1["oth_votes"].sum()
tot = df1["tot_votes"].sum()

# create new dataframe with summary data
summary = pd.DataFrame({"state_abbr":state_abbr,"fips":fips,"dem":dem, 
                        "rep": rep, "oth": oth, "tot": tot})
summary.head()
# Out:
#                      state_abbr    fips      dem      rep     oth      tot
# year state   county
# 2000 Alabama Autauga         AL  1001.0   4942.0  11993.0   273.0  17208.0
#              Baldwin         AL  1003.0  13997.0  40872.0  1611.0  56480.0
#              Barbour         AL  1005.0   5188.0   5096.0   111.0  10395.0
#              Bibb            AL  1007.0   2710.0   4273.0   118.0   7101.0
#              Blount          AL  1009.0   4977.0  12667.0   329.0  17973.0

# %%
# show year and state in every row
summary.reset_index()
# Out:
#        year      state       county state_abbr     fips      dem       rep  \
# 0      2000    Alabama      Autauga         AL   1001.0   4942.0   11993.0
# 1      2000    Alabama      Baldwin         AL   1003.0  13997.0   40872.0
# 2      2000    Alabama      Barbour         AL   1005.0   5188.0    5096.0
# 3      2000    Alabama         Bibb         AL   1007.0   2710.0    4273.0
# 4      2000    Alabama       Blount         AL   1009.0   4977.0   12667.0
# 5      2000    Alabama      Bullock         AL   1011.0   3395.0    1433.0
# 6      2000    Alabama       Butler         AL   1013.0   3606.0    4127.0
# 7      2000    Alabama      Calhoun         AL   1015.0  15781.0   22306.0
# 8      2000    Alabama     Chambers         AL   1017.0   5616.0    6037.0
# 9      2000    Alabama     Cherokee         AL   1019.0   3497.0    4154.0
# 10     2000    Alabama      Chilton         AL   1021.0   4806.0   10066.0
# 11     2000    Alabama      Choctaw         AL   1023.0   3707.0    3600.0
# 12     2000    Alabama       Clarke         AL   1025.0   4679.0    5988.0
# 13     2000    Alabama         Clay         AL   1027.0   2045.0    3719.0
# 14     2000    Alabama     Cleburne         AL   1029.0   1664.0    3333.0
# 15     2000    Alabama       Coffee         AL   1031.0   5220.0    9938.0
# 16     2000    Alabama      Colbert         AL   1033.0  10543.0   10518.0
# 17     2000    Alabama      Conecuh         AL   1035.0   2783.0    2699.0
# 18     2000    Alabama        Coosa         AL   1037.0   2104.0    2382.0
# 19     2000    Alabama    Covington         AL   1039.0   4440.0    8961.0
# 20     2000    Alabama     Crenshaw         AL   1041.0   1934.0    2793.0
# 21     2000    Alabama      Cullman         AL   1043.0   9758.0   19157.0
# 22     2000    Alabama         Dale         AL   1045.0   4906.0   10593.0
# 23     2000    Alabama       Dallas         AL   1047.0  10967.0    7360.0
# 24     2000    Alabama       DeKalb         AL   1049.0   7056.0   12827.0
# 25     2000    Alabama       Elmore         AL   1051.0   6652.0   16777.0
# 26     2000    Alabama     Escambia         AL   1053.0   4523.0    6975.0
# 27     2000    Alabama       Etowah         AL   1055.0  17433.0   21087.0
# 28     2000    Alabama      Fayette         AL   1057.0   3064.0    4582.0
# 29     2000    Alabama     Franklin         AL   1059.0   4793.0    6119.0
# ...     ...        ...          ...        ...      ...      ...       ...
# 15718  2016  Wisconsin     Washburn         WI  55129.0   3284.0    5404.0
# 15719  2016  Wisconsin   Washington         WI  55131.0  20855.0   51729.0
# 15720  2016  Wisconsin     Waukesha         WI  55133.0  79200.0  142521.0
# 15721  2016  Wisconsin      Waupaca         WI  55135.0   8440.0   16189.0
# 15722  2016  Wisconsin     Waushara         WI  55137.0   3792.0    7669.0
# 15723  2016  Wisconsin    Winnebago         WI  55139.0  37054.0   43448.0
# 15724  2016  Wisconsin         Wood         WI  55141.0  14232.0   21503.0
# 15725  2016    Wyoming       Albany         WY  56001.0   6890.0    7602.0
# 15726  2016    Wyoming     Big Horn         WY  56003.0    604.0    4067.0
# 15727  2016    Wyoming     Campbell         WY  56005.0   1324.0   15778.0
# 15728  2016    Wyoming       Carbon         WY  56007.0   1279.0    4409.0
# 15729  2016    Wyoming     Converse         WY  56009.0    668.0    5520.0
# 15730  2016    Wyoming        Crook         WY  56011.0    273.0    3348.0
# 15731  2016    Wyoming      Fremont         WY  56013.0   4200.0   11167.0
# 15732  2016    Wyoming       Goshen         WY  56015.0    924.0    4418.0
# 15733  2016    Wyoming  Hot Springs         WY  56017.0    400.0    1939.0
# 15734  2016    Wyoming      Johnson         WY  56019.0    638.0    3477.0
# 15735  2016    Wyoming      Laramie         WY  56021.0  11573.0   24847.0
# 15736  2016    Wyoming      Lincoln         WY  56023.0   1105.0    6779.0
# 15737  2016    Wyoming      Natrona         WY  56025.0   6577.0   23552.0
# 15738  2016    Wyoming     Niobrara         WY  56027.0    115.0    1116.0
# 15739  2016    Wyoming         Park         WY  56029.0   2535.0   11115.0
# 15740  2016    Wyoming       Platte         WY  56031.0    719.0    3437.0
# 15741  2016    Wyoming     Sheridan         WY  56033.0   2927.0   10266.0
# 15742  2016    Wyoming     Sublette         WY  56035.0    644.0    3409.0
# 15743  2016    Wyoming   Sweetwater         WY  56037.0   3231.0   12154.0
# 15744  2016    Wyoming        Teton         WY  56039.0   7314.0    3921.0
# 15745  2016    Wyoming        Uinta         WY  56041.0   1202.0    6154.0
# 15746  2016    Wyoming     Washakie         WY  56043.0    532.0    2911.0
# 15747  2016    Wyoming       Weston         WY  56045.0    299.0    3033.0
#
#            oth       tot
# 0        273.0   17208.0
# 1       1611.0   56480.0
# 2        111.0   10395.0
# 3        118.0    7101.0
# 4        329.0   17973.0
# 5         76.0    4904.0
# 6         70.0    7803.0
# 7        822.0   38909.0
# 8        181.0   11834.0
# 9        172.0    7823.0
# 10       220.0   15092.0
# 11        67.0    7374.0
# 12        85.0   10752.0
# 13       119.0    5883.0
# 14        95.0    5092.0
# 15       276.0   15434.0
# 16       471.0   21532.0
# 17        69.0    5551.0
# 18        81.0    4567.0
# 19       212.0   13613.0
# 20        68.0    4795.0
# 21       610.0   29525.0
# 22       307.0   15806.0
# 23       137.0   18464.0
# 24       402.0   20285.0
# 25       375.0   23804.0
# 26       162.0   11660.0
# 27       828.0   39348.0
# 28       162.0    7808.0
# 29       191.0   11103.0
# ...        ...       ...
# 15718    460.0    9148.0
# 15719   5419.0   78003.0
# 15720  17321.0  239042.0
# 15721   1395.0   26024.0
# 15722    538.0   11999.0
# 15723   6642.0   87144.0
# 15724   2065.0   37800.0
# 15725   2568.0   17060.0
# 15726    646.0    5317.0
# 15727   1097.0   18199.0
# 15728    686.0    6374.0
# 15729    466.0    6654.0
# 15730    205.0    3826.0
# 15731   1656.0   17023.0
# 15732    454.0    5796.0
# 15733    247.0    2586.0
# 15734    302.0    4417.0
# 15735   4549.0   40969.0
# 15736    991.0    8875.0
# 15737   3219.0   33348.0
# 15738     83.0    1314.0
# 15739   1445.0   15095.0
# 15740    373.0    4529.0
# 15741   1317.0   14510.0
# 15742    337.0    4390.0
# 15743   1745.0   17130.0
# 15744   1392.0   12627.0
# 15745   1114.0    8470.0
# 15746    371.0    3814.0
# 15747    194.0    3526.0
#
# [15748 rows x 9 columns]

# %%
import sqlalchemy
import psycopg2
from sqlalchemy import create_engine
engine = create_engine('postgresql://postgres:Peter@1947@localhost/VotingProject')
summary.to_sql("pres_hist",engine)
